# %%
import pandas as pd

# %%
df = pd.read_csv('./data/Books.csv')
df
# Out:
#     Identifier                                  Edition Statement  \
# 0          206                                                NaN
# 1          216                                                NaN
# 2          218                                                NaN
# 3          472                                                NaN
# 4          480                       A new edition, revised, etc.
# 5          481                      Fourth edition, revised, etc.
# 6          519                                                NaN
# 7          667                                                NaN
# 8          874                                                NaN
# 9         1143                                                NaN
# 10        1280                                                NaN
# 11        1808                                                NaN
# 12        1905                                                NaN
# ...

# %%
df['Place of Publication'].value_counts().plot.pie()
